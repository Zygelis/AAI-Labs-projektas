# %%
import pandas as pd
import os

# Change working directory
new_directory = "C:\\Users\\Zygis\\Desktop\\AAI-Labs-projektas"
os.chdir(new_directory)

# Read in data
df = pd.read_excel("WEOOct2020all.xls", engine="xlrd")

# TASK 5
# Find all the data fields from the year 2015 that are present in most of the countries.

# Count how many countries are in the dataset
countries = len(df["Country"].unique())

# Select most_countries threshold. I chose that most countries are 75% of the countries.
most_countries = countries * 0.75

# Group data by the WEO Subject Code and count how many countries have data in 2015
df_count = df.groupby("WEO Subject Code")[2015].count()

# Filter dataframe to only include data fields that are present in most of the countries
df_most = df_count[df_count > most_countries]
print("Data fields that are present in most of the countries: ")
print(df_most.index)
print("\n")

# In one line
df_most_1 = df.groupby("WEO Subject Code")[2015].count()[lambda x: x > most_countries]
print("Data fields that are present in most of the countries: ")
print(df_most_1.index)
print("\n")

# Find Weo Subject Code descriptions
df_desc = df[["WEO Subject Code", "Subject Descriptor"]].drop_duplicates()
print("Data fields that are present in most of the countries with descriptions: ")
print(df_desc[df_desc["WEO Subject Code"].isin(df_most.index)])
# Out:
# Data fields that are present in most of the countries:
# Index(['BCA', 'BCA_NGDPD', 'GGR', 'GGR_NGDP', 'GGX', 'GGXCNL', 'GGXCNL_NGDP',
#        'GGXONLB', 'GGXONLB_NGDP', 'GGXWDG', 'GGXWDG_NGDP', 'GGX_NGDP', 'LP',
#        'NGDP', 'NGDPD', 'NGDPDPC', 'NGDPPC', 'NGDPRPC', 'NGDPRPPPPC', 'NGDP_D',
#        'NGDP_FY', 'NGDP_R', 'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPI',
#        'PCPIE', 'PCPIEPCH', 'PCPIPCH', 'PPPEX', 'PPPGDP', 'PPPPC', 'PPPSH',
#        'TMG_RPCH', 'TM_RPCH', 'TXG_RPCH', 'TX_RPCH'],
#       dtype='object', name='WEO Subject Code')
#
#
# Data fields that are present in most of the countries:
# Index(['BCA', 'BCA_NGDPD', 'GGR', 'GGR_NGDP', 'GGX', 'GGXCNL', 'GGXCNL_NGDP',
#        'GGXONLB', 'GGXONLB_NGDP', 'GGXWDG', 'GGXWDG_NGDP', 'GGX_NGDP', 'LP',
#        'NGDP', 'NGDPD', 'NGDPDPC', 'NGDPPC', 'NGDPRPC', 'NGDPRPPPPC', 'NGDP_D',
#        'NGDP_FY', 'NGDP_R', 'NGDP_RPCH', 'NGSD_NGDP', 'NID_NGDP', 'PCPI',
#        'PCPIE', 'PCPIEPCH', 'PCPIPCH', 'PPPEX', 'PPPGDP', 'PPPPC', 'PPPSH',
#        'TMG_RPCH', 'TM_RPCH', 'TXG_RPCH', 'TX_RPCH'],
#       dtype='object', name='WEO Subject Code')
#
#
# Data fields that are present in most of the countries with descriptions:
#    WEO Subject Code                                 Subject Descriptor
# 0            NGDP_R            Gross domestic product, constant prices
# 1         NGDP_RPCH            Gross domestic product, constant prices
# 2              NGDP             Gross domestic product, current prices
# 3             NGDPD             Gross domestic product, current prices
# 4            PPPGDP             Gross domestic product, current prices
# 5            NGDP_D                   Gross domestic product, deflator
# 6           NGDPRPC  Gross domestic product per capita, constant pr...
# 7        NGDPRPPPPC  Gross domestic product per capita, constant pr...
# 8            NGDPPC  Gross domestic product per capita, current prices
# 9           NGDPDPC  Gross domestic product per capita, current prices
# 10            PPPPC  Gross domestic product per capita, current prices
# 12            PPPSH  Gross domestic product based on purchasing-pow...
# 13            PPPEX                        Implied PPP conversion rate
# 14         NID_NGDP                                   Total investment
# 15        NGSD_NGDP                             Gross national savings
# 16             PCPI                 Inflation, average consumer prices
# 17          PCPIPCH                 Inflation, average consumer prices
# 18            PCPIE           Inflation, end of period consumer prices
# 19         PCPIEPCH           Inflation, end of period consumer prices
# 21          TM_RPCH            Volume of imports of goods and services
# 22         TMG_RPCH                         Volume of Imports of goods
# 23          TX_RPCH            Volume of exports of goods and services
# 24         TXG_RPCH                         Volume of exports of goods
# 27               LP                                         Population
# 28              GGR                         General government revenue
# 29         GGR_NGDP                         General government revenue
# 30              GGX               General government total expenditure
# 31         GGX_NGDP               General government total expenditure
# 32           GGXCNL           General government net lending/borrowing
# 33      GGXCNL_NGDP           General government net lending/borrowing
# 36          GGXONLB   General government primary net lending/borrowing
# 37     GGXONLB_NGDP   General government primary net lending/borrowing
# 40           GGXWDG                      General government gross debt
# 41      GGXWDG_NGDP                      General government gross debt
# 42          NGDP_FY  Gross domestic product corresponding to fiscal...
# 43              BCA                            Current account balance
# 44        BCA_NGDPD                            Current account balance
